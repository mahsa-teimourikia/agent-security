# %% [markdown]
# # Security evaluation lab
#
# Turn attack cases into a release gate and inspect failures.

# %%
from pathlib import Path
exec(Path('../advanced/01_attack_evaluation.py').read_text())
